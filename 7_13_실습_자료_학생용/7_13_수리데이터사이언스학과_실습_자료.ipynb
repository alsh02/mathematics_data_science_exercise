# %% [markdown]
# # 실습 1. 수학을 이용하여 이미지 데이터 처리하기
# 비정형 데이터 중 하나인 이미지 데이터를 처리해 보도록 하자.

# %% [markdown]
# #  OpenCV
#
# 이미지 처리의 핵심은 색, 픽셀 간의 상호 관계, 물체 배치 등과 같은 이미지의 다른 속성을 사용하여 <br>
# 물체, 윤곽선 등 이미지 특징이라고 부르는 유용한 정보를 추출하는 것이다. 파이선의 이미지 처리 및 <br>
# 컴퓨터 비전을 위한 오픈 소스 라이브러리인 OpenCV를 활용하여 이미지 처리를 해 보자.

# %% [markdown]
# **1) 원하는 이미지 파일 2개를 불러오고, 그 파일들의 타입을 출력해보자.**
#
#
#  **이미지 불러오는 방법** <br>
#
# 1) 왼쪽 4번째 아이콘(파일)을 누른다. <br>
# 2) 4가지 아이콘 중 첫번째(세션 저장소에 업로드)를 눌러서 파일을 불러온다.<br>
# 3) 새 노트를 눌러서 다음 코드를 작성한다. 단, 파일명은 자신이 저장한 사진의
# 파일명으로 설정한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1)번 코드 작성하기

# %% [markdown]
# **2) 각각의 이미지를 표시하고, shape과 size를 확인해보자.**
#
# 각각의 출력 결과가 무엇을 의미하는지를 찾아서 작성해보자.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 두번째 이미지는 어떻게 해야 할지 생각해보자.

# %%
# 2)번의 첫번째 이미지 코드 작성하기

# %%
# 2)번의 두번째 이미지 코드 작성하기

# %% [markdown]
# **3) 이미지를 잘라보자.**
#
# 자신이 직접 범위를 지정해서 원하는 부분만 보이게 해보자. <br>
# <br>
#
# 참고 : 파이썬에서 리스트는 0부터 시작한다. <br>
# [a:b]로 리스트를 슬라이싱 한다는 의미는 a+1부터 b행까지를 의미한다. <br>
# 따라서 밑의 사진은 141-250행, 401-620열에 해당하는 부분을 <br>
# 잘라서 출력한 것이다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 3)번 코드 작성하기

# %% [markdown]
# **4) 이미지 데이터의 변숫값(픽셀값)을 출력해보자.**
#
# ![image.png](data:image/png;base64,...)
#
# 참고 : OpenCV에서는 B, G, R 순서로 이루어져있다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 4)번 코드 작성하기

# %% [markdown]
# **5) 이미지의 특정 좌표의 색상값을 출력해보자.**
#
# 자신이 원하는 좌표의 색상값을 출력해보자. <br>
#
# ![image.png](data:image/png;base64,...)
#
# 참고 : [200, 100]은 201행 101열을 의미한다. (파이썬에서 리스트는 0부터 시작)

# %%
# 5)번 코드 작성하기

# %% [markdown]
# **6) 두 이미지를 2가지 방법으로 합쳐보자. (직접 합치기, add() 사용하기)**
#
# 1. 직접 합치기 <br>
# 두 개의 이미지를 더하는 식은 ‘img=img1+img2’로 쓸 수 있다. <br>
# 이렇게 두 개의 이미지를 더해 새로운 이미지를 생성하려면 <br>
# img1과 img2는 동일한 크기의 동일한 데이터 타입이어야 한다. <br>
# 이 연산에 서 각 픽셀들을 더한 값이 255보다 크면 그 값을 256으로 나눈 나머지가 픽셀값이 된다. <br>
# 예를 들어, 두 픽셀을 더한 값이 260이라면, 픽셀값은 4로 변환된다.<br>
# <br>
# 2. add() 사용하기 <br>
# add()를 이용하면 두 픽셀을 더한 값이 255보다 크면 255로 정한다. <br>
#
# (677, 387)로 되어 있는 것을 자신의 첫 번째 사진 크기로 설정해서 실행해보자.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
# 6)번의 직접 합치기를 이용한 코드 작성하기

# %%
# 6)번의 add()를 이용한 코드 작성하기

# %% [markdown]
# **7) 이미지에 다양한 색 필터를 적용해보자.**
#
# 가중치를 변경하면서 다양한 색 필터를 적용해보자. <br>
# 참고 : 회색의 가중치는 rgb순서대로 0.2989, 0.5870, 0.1140이다. <br>
# 가중치의 합은 1을 유지해야 한다. 1이 아닐경우 출력 결과가 이상할 수 있다. <br>
# **:** 은 전체를 의미한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 7)번 코드 작성하기

# %% [markdown]
# # 실습 2. 논리를 바탕으로 문제 해결하기
# 정형 데이터인 데이터프레임을 처리하여 시각화 해보자.

# %% [markdown]
# pandas는 데이터를 분석하기 위한 파이선 라이브러리로, 상대적으로 많은 양의 데이터를 정리하는 <br>
# 가장 기본적인 도구이다. pandas는 엑셀을 다루듯이 파이선으로 데이터 구조를 만들 수 있으며, 행과 열로 <br>
# 이루어진 데이터 객체를 만들어 다룰 수도 있다. pandas와 함께 배열 구조나 랜덤 값 생성 등의 기능을 <br>
# 활용하기 위해 NumPy 라이브러리를 함께 불러오기도 한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
